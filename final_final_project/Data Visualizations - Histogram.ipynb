# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("results.csv")

# %%
df.head()
# Out:
#        Name                            Unchunk #  # Correct (UC)  \
# 0    Alexis  17297907390238149226414802872582839               5
# 1  Angelica  59295948629770291220106005306959668               6
# 2    Anjali  56334420779787820951725598872575781               4
# 3    Ariana  82218343732245991093852425971664767               4
# 4     Avery  05596400928662988889364570084697837               4
#
#                                       Chunk #  # Correct (C)
# 0  10611 12312 93085 55605 10581 81454 25792'             10
# 1   26772 88425 58101 80348 61248 87767 52764             10
# 2   10182 13351 48203 27047 01205 86256 37184             11
# 3   37920 25089 25793 89070 97024 00241 98989              6
# 4   11062 11557 31562 12302 84012 50533 94514              1

# %%
unchunk = df["# Correct (UC)"]
chunk = df["# Correct (C)"]

# %%
len(unchunk)**(1/2)
# Out:
# 4.47213595499958

# %%
len(chunk)**(1/2)
# Out:
# 4.47213595499958

# %%
plt.hist(chunk, bins = 5, color = "skyblue", label = "chunked correct #")
plt.hist(unchunk, bins = 5, color = "indigo", label = "unchunked correct #")
plt.legend()
plt.title("Comparison of the # of Correct Numbers Chunked vs Unchunked")
plt.ylabel("Number of Subjects")
plt.xlabel("Amount of Correct Numbers")
plt.savefig("chunk5hist.png")
plt.show()

# %%
plt.hist(chunk, bins = 5, color = "skyblue")
plt.title("Amount of Correct Numbers, Chunked")
plt.ylabel("Number of Subjects")
plt.xlabel("Amount of Correct Numbers")
plt.savefig("chunk5chunkhist.png")
plt.show()

# %%
plt.hist(unchunk, bins = 5, color = "indigo")
plt.title("Amount of Correct Numbers, Unchunked")
plt.ylabel("Number of Subjects")
plt.xlabel("Amount of Correct Numbers")
plt.savefig("chunk5unchunkhist.png")
plt.show()

# %%
# JUST FOR FUN AND STOLEN FROM MATPLOTLIB BUT I PLAYED AROUND WITH THE DIMENSIONS
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-500, 5, 0.25)
Y = np.arange(-10, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.magma)

plt.show()
